# %% [markdown]
# # Limpieza de datos con Pandas

# %%
import requests
import pandas as pd
import hashlib

# %% [markdown]
# ## Extrar data api meetup

# %%
members = requests.get('https://api.meetup.com/pyladiesEc/members')

# %%
members?

# %%
members.json()
# Out:
# [{'id': 274228617,
#   'name': 'Pyladies E.',
#   'bio': 'Es un grupo que tiene como objetivo proporcionar una red de apoyo para las mujeres y un puente al mundo de Python. ¡Todos son bienvenidos!',
#   'status': 'active',
#   'joined': 1549913446000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 284993895,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/d/2/8/7/highres_284993895.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/d/2/8/7/member_284993895.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/2/8/7/thumb_284993895.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552106450000,
#    'created': 1550521540000,
#    'updated': 1550523326000,
#    'role': 'organizer',
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/274228617/'},
#   'is_pro_admin': False},
#  {'id': 213001949,
#   'name': 'Elena C.',
#   'bio': 'Organizadora de R-Ladies Quito / Usuaria de R / Docente / Científica de Datos',
#   'status': 'active',
#   'joined': 1473956368000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 265497196,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/d/f/6/c/highres_265497196.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/d/f/6/c/member_265497196.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/f/6/c/thumb_265497196.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552105491000,
#    'created': 1550661380000,
#    'updated': 1550661380000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/213001949/'},
#   'is_pro_admin': False},
#  {'id': 249923190,
#   'name': 'Marcelo C.',
#   'status': 'active',
#   'joined': 1520684404000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 275420286,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/4/f/3/e/highres_275420286.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/4/f/3/e/member_275420286.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/f/3/e/thumb_275420286.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552102958000,
#    'created': 1550715733000,
#    'updated': 1550715733000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/249923190/'},
#   'is_pro_admin': False},
#  {'id': 255612452,
#   'name': 'David D.',
#   'status': 'active',
#   'joined': 1527704432000,
#   'city': 'Cuenca',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -2.9,
#   'lon': -79.01,
#   'photo': {'id': 277634915,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/3/a/4/3/highres_277634915.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/3/a/4/3/member_277634915.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/a/4/3/thumb_277634915.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552101439000,
#    'created': 1551304748000,
#    'updated': 1551304748000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/255612452/'},
#   'is_pro_admin': False},
#  {'id': 276160008,
#   'name': 'Carlos T.',
#   'status': 'active',
#   'joined': 1552089985000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'group_profile': {'status': 'active',
#    'visited': 1552090034000,
#    'created': 1552090034000,
#    'updated': 1552090034000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'Telegram'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'de todo en general'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276160008/'},
#   'is_pro_admin': False},
#  {'id': 163123722,
#   'name': 'Francisco Silva G.',
#   'status': 'active',
#   'joined': 1408824136000,
#   'city': 'Buenos Aires',
#   'country': 'ar',
#   'localized_country_name': 'Argentina',
#   'lat': -34.61,
#   'lon': -58.37,
#   'photo': {'id': 220933812,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/3/5/f/4/highres_220933812.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/3/5/f/4/member_220933812.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/5/f/4/thumb_220933812.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552086286000,
#    'created': 1552086286000,
#    'updated': 1552086286000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'amigas'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'analítica de datos'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/163123722/'},
#   'is_pro_admin': False},
#  {'id': 276151888,
#   'name': 'Jessica M.',
#   'bio': 'entusiasta por aprender cosas relacionadas con la tecnología.',
#   'status': 'active',
#   'joined': 1552080861000,
#   'city': 'Loja',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -3.99,
#   'lon': -79.21,
#   'group_profile': {'status': 'active',
#    'visited': 1552081166000,
#    'created': 1552081166000,
#    'updated': 1552081166000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'facebook'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'aprender a programar.'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276151888/'},
#   'is_pro_admin': False},
#  {'id': 276151566,
#   'name': 'Silvy V.',
#   'bio': 'Estudiante de Maestría en Sistemas Inteligentes en la Escuela Politécnica Nacional.',
#   'status': 'active',
#   'joined': 1552080453000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285836294,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/d/b/e/6/highres_285836294.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/d/b/e/6/member_285836294.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/b/e/6/thumb_285836294.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552080611000,
#    'created': 1552080611000,
#    'updated': 1552080611000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'Redes Sociales'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'python'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276151566/'},
#   'is_pro_admin': False},
#  {'id': 256300260,
#   'name': 'Leo C.',
#   'status': 'active',
#   'joined': 1528495887000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 277908461,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/b/d/4/d/highres_277908461.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/b/d/4/d/member_277908461.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/d/4/d/thumb_277908461.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552078775000,
#    'created': 1552078775000,
#    'updated': 1552078775000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'meet up'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'machine learning'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/256300260/'},
#   'is_pro_admin': False},
#  {'id': 235853540,
#   'name': 'Luis Paz y M.',
#   'status': 'active',
#   'joined': 1504757368000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 270416997,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/d/e/a/5/highres_270416997.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/d/e/a/5/member_270416997.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/e/a/5/thumb_270416997.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552077570000,
#    'created': 1551042476000,
#    'updated': 1551042476000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/235853540/'},
#   'is_pro_admin': False},
#  {'id': 244641411,
#   'name': 'Andrea C.',
#   'status': 'active',
#   'joined': 1514321784000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 273313080,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/3/3/1/8/highres_273313080.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/3/3/1/8/member_273313080.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/3/1/8/thumb_273313080.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552070345000,
#    'created': 1552070345000,
#    'updated': 1552070345000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'gmail'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'manejo de datos en general'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/244641411/'},
#   'is_pro_admin': False},
#  {'id': 274959456,
#   'name': 'Jorge A.',
#   'status': 'active',
#   'joined': 1550775169000,
#   'city': 'Cuenca',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -2.9,
#   'lon': -79.01,
#   'photo': {'id': 285317717,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/4/5/3/5/highres_285317717.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/4/5/3/5/member_285317717.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/5/3/5/thumb_285317717.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552062632000,
#    'created': 1552062632000,
#    'updated': 1552062632000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'Por el grupo de Python Quito '},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'Programación de Raspberry en Python '}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/274959456/'},
#   'is_pro_admin': False},
#  {'id': 264099108,
#   'name': 'Ingrid',
#   'status': 'active',
#   'joined': 1537920016000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 280981629,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/6/5/d/highres_280981629.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/6/5/d/member_280981629.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/5/d/thumb_280981629.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552062452000,
#    'created': 1550682417000,
#    'updated': 1550682417000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/264099108/'},
#   'is_pro_admin': False},
#  {'id': 276101328,
#   'name': 'Iván P.',
#   'status': 'active',
#   'joined': 1552014741000,
#   'city': 'Guayaquil',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -2.21,
#   'lon': -79.9,
#   'photo': {'id': 285810280,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/7/6/4/8/highres_285810280.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/7/6/4/8/member_285810280.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/6/4/8/thumb_285810280.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552061417000,
#    'created': 1552061417000,
#    'updated': 1552061417000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?',
#      'answer': 'Novia'},
#     {'question_id': 8948672,
#      'question': '¿Que temas te gustaría conocer?',
#      'answer': 'Tecnología '}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276101328/'},
#   'is_pro_admin': False},
#  {'id': 235493187,
#   'name': 'Andrea',
#   'status': 'active',
#   'joined': 1504384147000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 279505242,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/6/2/9/a/highres_279505242.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/6/2/9/a/member_279505242.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/2/9/a/thumb_279505242.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552061024000,
#    'created': 1550691753000,
#    'updated': 1550691753000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/235493187/'},
#   'is_pro_admin': False},
#  {'id': 245597047,
#   'name': 'Katherine M.',
#   'status': 'active',
#   'joined': 1515434709000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 273639156,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/9/8/f/4/highres_273639156.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/9/8/f/4/member_273639156.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/8/f/4/thumb_273639156.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552049994000,
#    'created': 1551224841000,
#    'updated': 1551224841000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/245597047/'},
#   'is_pro_admin': False},
#  {'id': 227211202,
#   'name': 'Rommel Gutiérrez R.',
#   'status': 'active',
#   'joined': 1494276593000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 266752098,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/c/b/8/2/highres_266752098.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/c/b/8/2/member_266752098.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/b/8/2/thumb_266752098.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552044284000,
#    'created': 1551462683000,
#    'updated': 1551462683000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/227211202/'},
#   'is_pro_admin': False},
#  {'id': 250902965,
#   'name': 'Gabi M.',
#   'status': 'active',
#   'joined': 1521907209000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 275808782,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/b/e/8/e/highres_275808782.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/b/e/8/e/member_275808782.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/e/8/e/thumb_275808782.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552043737000,
#    'created': 1551910945000,
#    'updated': 1551910945000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/250902965/'},
#   'is_pro_admin': False},
#  {'id': 273201949,
#   'name': 'Mayra O.',
#   'status': 'active',
#   'joined': 1548695415000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 284564436,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/a/d/9/4/highres_284564436.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/a/d/9/4/member_284564436.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/d/9/4/thumb_284564436.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552041469000,
#    'created': 1550775395000,
#    'updated': 1550775395000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/273201949/'},
#   'is_pro_admin': False},
#  {'id': 247732691,
#   'name': 'Gaby G.',
#   'bio': 'Desarrolladora de Software',
#   'status': 'active',
#   'joined': 1518021245000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 274529570,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/7/3/8/2/highres_274529570.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/7/3/8/2/member_274529570.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/3/8/2/thumb_274529570.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'title': 'PyLady',
#    'status': 'active',
#    'visited': 1552030736000,
#    'created': 1550625525000,
#    'updated': 1551629584000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/247732691/'},
#   'is_pro_admin': False},
#  {'id': 276020102,
#   'name': 'Mirely T.',
#   'status': 'active',
#   'joined': 1551926989000,
#   'city': 'Guayaquil',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -2.21,
#   'lon': -79.9,
#   'photo': {'id': 285772660,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/c/d/b/4/highres_285772660.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/c/d/b/4/member_285772660.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/d/b/4/thumb_285772660.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1552011561000,
#    'created': 1551927344000,
#    'updated': 1551927344000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276020102/'},
#   'is_pro_admin': False},
#  {'id': 276089997,
#   'name': 'Daya',
#   'status': 'active',
#   'joined': 1552000823000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'group_profile': {'status': 'active',
#    'visited': 1552001330000,
#    'created': 1552001330000,
#    'updated': 1552001330000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276089997/'},
#   'is_pro_admin': False},
#  {'id': 267202489,
#   'name': 'Andrea Esther M.',
#   'status': 'active',
#   'joined': 1541513415000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 282182737,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/a/b/1/highres_282182737.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/a/b/1/member_282182737.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/b/1/thumb_282182737.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551991909000,
#    'created': 1550628307000,
#    'updated': 1550628307000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/267202489/'},
#   'is_pro_admin': False},
#  {'id': 268797456,
#   'name': 'Paola C.',
#   'status': 'active',
#   'joined': 1543508424000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 282812113,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/7/d/7/1/highres_282812113.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/7/d/7/1/member_282812113.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/d/7/1/thumb_282812113.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551979004000,
#    'created': 1551979004000,
#    'updated': 1551979004000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/268797456/'},
#   'is_pro_admin': False},
#  {'id': 135803972,
#   'name': 'rojoyin',
#   'status': 'active',
#   'joined': 1393988782000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 265333270,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/3/3/d/6/highres_265333270.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/3/3/d/6/member_265333270.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/3/d/6/thumb_265333270.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551978872000,
#    'created': 1550690520000,
#    'updated': 1550690520000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/135803972/'},
#   'is_pro_admin': False},
#  {'id': 276017288,
#   'name': 'Eduardo R.',
#   'status': 'active',
#   'joined': 1551923430000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285771282,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/c/8/5/2/highres_285771282.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/c/8/5/2/member_285771282.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/8/5/2/thumb_285771282.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551923447000,
#    'created': 1551923447000,
#    'updated': 1551923447000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276017288/'},
#   'is_pro_admin': False},
#  {'id': 276013944,
#   'name': 'Jimmy G.',
#   'status': 'active',
#   'joined': 1551919402000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285769528,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/c/1/7/8/highres_285769528.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/c/1/7/8/member_285769528.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/1/7/8/thumb_285769528.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551919534000,
#    'created': 1551919534000,
#    'updated': 1551919534000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/276013944/'},
#   'is_pro_admin': False},
#  {'id': 275999062,
#   'name': 'Sandra R.',
#   'status': 'active',
#   'joined': 1551903329000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285762009,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/a/4/1/9/highres_285762009.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/a/4/1/9/member_285762009.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/4/1/9/thumb_285762009.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551903787000,
#    'created': 1551903787000,
#    'updated': 1551903787000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/275999062/'},
#   'is_pro_admin': False},
#  {'id': 275993243,
#   'name': 'Sttefy C.',
#   'status': 'active',
#   'joined': 1551901176000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'group_profile': {'status': 'active',
#    'visited': 1551901214000,
#    'created': 1551901214000,
#    'updated': 1551901214000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/275993243/'},
#   'is_pro_admin': False},
#  {'id': 274878775,
#   'name': 'Paolo P',
#   'status': 'active',
#   'joined': 1550682678000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285280202,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/9/d/0/a/highres_285280202.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/9/d/0/a/member_285280202.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/d/0/a/thumb_285280202.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1551886167000,
#    'created': 1551891643000,
#    'updated': 1551891643000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/274878775/'},
#   'is_pro_admin': False},
#  {'id': 143902142,
#   'name': 'Katya',
#   'status': 'active',
#   'joined': 1398561957000,
#   'city': 'Bethesda',
#   'country': 'us',
#   'localized_country_name': 'USA',
#   'state': 'MD',
#   'lat': 38.98,
#   'lon': -77.1,
#   'photo': {'id': 265632334,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/3/0/2/e/highres_265632334.jpeg',
# ...
#   'status': 'active',
#   'joined': 1377743733000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 277630980,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/2/a/e/4/highres_277630980.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/2/a/e/4/member_277630980.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/2/a/e/4/thumb_277630980.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550721779000,
#    'created': 1550721779000,
#    'updated': 1550721779000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/108842032/'},
#   'is_pro_admin': False},
#  {'id': 262397218,
#   'name': 'Roxana',
#   'status': 'active',
#   'joined': 1535908543000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 280295458,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/8/a/8/2/highres_280295458.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/8/a/8/2/member_280295458.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/a/8/2/thumb_280295458.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550683865000,
#    'created': 1550683865000,
#    'updated': 1550683865000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/262397218/'},
#   'is_pro_admin': False},
#  {'id': 259539676,
#   'name': 'Elymar A.',
#   'status': 'active',
#   'joined': 1532393560000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 279137929,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/4/6/0/9/highres_279137929.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/4/6/0/9/member_279137929.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/6/0/9/thumb_279137929.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550683543000,
#    'created': 1550683543000,
#    'updated': 1550683543000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/259539676/'},
#   'is_pro_admin': False},
#  {'id': 194969949,
#   'name': 'Anita S.',
#   'status': 'active',
#   'joined': 1446426185000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.18,
#   'lon': -78.49,
#   'photo': {'id': 251039573,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/e/8/b/5/highres_251039573.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/e/8/b/5/member_251039573.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/8/b/5/thumb_251039573.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550682205000,
#    'created': 1550682205000,
#    'updated': 1550682205000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/194969949/'},
#   'is_pro_admin': False},
#  {'id': 116955082,
#   'name': 'damian',
#   'status': 'active',
#   'joined': 1382564434000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 256146960,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/1/b/3/0/highres_256146960.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/1/b/3/0/member_256146960.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/1/b/3/0/thumb_256146960.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550681949000,
#    'created': 1550681949000,
#    'updated': 1550681949000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/116955082/'},
#   'is_pro_admin': False},
#  {'id': 246014322,
#   'name': 'Alicia V.',
#   'status': 'active',
#   'joined': 1515952874000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 273816204,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/8/d/6/c/highres_273816204.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/8/d/6/c/member_273816204.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/d/6/c/thumb_273816204.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550679200000,
#    'created': 1550679200000,
#    'updated': 1550679200000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/246014322/'},
#   'is_pro_admin': False},
#  {'id': 274838317,
#   'name': 'Andrea L.',
#   'status': 'active',
#   'joined': 1550630269000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285260451,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/4/f/e/3/highres_285260451.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/4/f/e/3/member_285260451.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/f/e/3/thumb_285260451.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550630294000,
#    'created': 1550630294000,
#    'updated': 1550630294000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/274838317/'},
#   'is_pro_admin': False},
#  {'id': 238198836,
#   'name': 'Eduardo V.',
#   'status': 'active',
#   'joined': 1507240232000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 271271802,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/2/e/1/a/highres_271271802.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/2/e/1/a/member_271271802.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/2/e/1/a/thumb_271271802.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550628715000,
#    'created': 1550628715000,
#    'updated': 1550628715000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/238198836/'},
#   'is_pro_admin': False},
#  {'id': 272997265,
#   'name': 'Martha San A.',
#   'status': 'active',
#   'joined': 1548473211000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 284487523,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/6/b/8/3/highres_284487523.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/6/b/8/3/member_284487523.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/b/8/3/thumb_284487523.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550628509000,
#    'created': 1550628509000,
#    'updated': 1550628509000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/272997265/'},
#   'is_pro_admin': False},
#  {'id': 274833896,
#   'name': 'Carolina B.',
#   'status': 'active',
#   'joined': 1550624902000,
#   'city': 'Quito',
#   'country': 'ec',
#   'localized_country_name': 'Ecuador',
#   'lat': -0.19,
#   'lon': -78.5,
#   'photo': {'id': 285258259,
#    'highres_link': 'https://secure.meetupstatic.com/photos/member/4/7/5/3/highres_285258259.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/4/7/5/3/member_285258259.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/7/5/3/thumb_285258259.jpeg',
#    'type': 'member',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'group_profile': {'status': 'active',
#    'visited': 1550624932000,
#    'created': 1550624932000,
#    'updated': 1550624932000,
#    'group': {'id': 31197321,
#     'urlname': 'pyladiesEc',
#     'name': 'PyLadies Ec',
#     'status': 'active',
#     'who': 'Members',
#     'members': 67,
#     'join_mode': 'open',
#     'localized_location': 'Quito, Ecuador',
#     'group_photo': {'id': 478801661,
#      'highres_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/highres_478801661.jpeg',
#      'photo_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/600_478801661.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/7/d/thumb_478801661.jpeg',
#      'type': 'event',
#      'base_url': 'https://secure.meetupstatic.com'}},
#    'answers': [{'question_id': 8948673,
#      'question': '¿Comó te enteraste Pyladies Ecuador?'},
#     {'question_id': 8948672, 'question': '¿Que temas te gustaría conocer?'}],
#    'link': 'https://www.meetup.com/pyladiesEc/members/274833896/'},
#   'is_pro_admin': False}]

# %% [markdown]
# ## Convertir  Json a DataFrame

# %%
membersDataFrame = pd.DataFrame(members.json())

# %%
membersDataFrame
# Out:
#                                                   bio    city country  \
# 0   Es un grupo que tiene como objetivo proporcion...   Quito      ec
# 1   Organizadora de R-Ladies Quito / Usuaria de R ...   Quito      ec
# 2                                                 NaN   Quito      ec
# 3                                                 NaN  Cuenca      ec
# 4                                                 NaN   Quito      ec
# ..                                                ...     ...     ...
# 62                                                NaN   Quito      ec
# 63                                                NaN   Quito      ec
# 64                                                NaN   Quito      ec
# 65                                                NaN   Quito      ec
# 66                                                NaN   Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552106450000,...  274228617
# 1   {'status': 'active', 'visited': 1552105491000,...  213001949
# 2   {'status': 'active', 'visited': 1552102958000,...  249923190
# 3   {'status': 'active', 'visited': 1552101439000,...  255612452
# 4   {'status': 'active', 'visited': 1552090034000,...  276160008
# ..                                                ...        ...
# 62  {'status': 'active', 'visited': 1550679200000,...  246014322
# 63  {'status': 'active', 'visited': 1550630294000,...  274838317
# 64  {'status': 'active', 'visited': 1550628715000,...  238198836
# 65  {'status': 'active', 'visited': 1550628509000,...  272997265
# 66  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined   lat localized_country_name    lon  \
# 0          False  1549913446000 -0.19                Ecuador -78.50
# 1          False  1473956368000 -0.19                Ecuador -78.50
# 2          False  1520684404000 -0.19                Ecuador -78.50
# 3          False  1527704432000 -2.90                Ecuador -79.01
# 4          False  1552089985000 -0.19                Ecuador -78.50
# ..           ...            ...   ...                    ...    ...
# 62         False  1515952874000 -0.19                Ecuador -78.50
# 63         False  1550630269000 -0.19                Ecuador -78.50
# 64         False  1507240232000 -0.19                Ecuador -78.50
# 65         False  1548473211000 -0.19                Ecuador -78.50
# 66         False  1550624902000 -0.19                Ecuador -78.50
#
#              name                                              photo state  \
# 0     Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...   NaN
# 1        Elena C.  {'id': 265497196, 'highres_link': 'https://sec...   NaN
# 2      Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...   NaN
# 3        David D.  {'id': 277634915, 'highres_link': 'https://sec...   NaN
# 4       Carlos T.                                                NaN   NaN
# ..            ...                                                ...   ...
# 62      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...   NaN
# 63      Andrea L.  {'id': 285260451, 'highres_link': 'https://sec...   NaN
# 64     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...   NaN
# 65  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...   NaN
# 66    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...   NaN
#
#     status
# 0   active
# 1   active
# 2   active
# 3   active
# 4   active
# ..     ...
# 62  active
# 63  active
# 64  active
# 65  active
# 66  active
#
# [67 rows x 14 columns]

# %%
membersDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 14 columns):
# bio                       7 non-null object
# city                      67 non-null object
# country                   67 non-null object
# group_profile             67 non-null object
# id                        67 non-null int64
# is_pro_admin              67 non-null bool
# joined                    67 non-null int64
# lat                       67 non-null float64
# localized_country_name    67 non-null object
# lon                       67 non-null float64
# name                      67 non-null object
# photo                     61 non-null object
# state                     3 non-null object
# status                    67 non-null object
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 6.9+ KB

# %% [markdown]
# #### Limit the number of rows to show

# %%
pd.options.display.max_rows = 12

# %%
#membersDataFrame.tail() #Five Last rows

# %%
#membersDataFrame.head()#Five first rows
# Out:
#                                                  bio    city country  \
# 0  Es un grupo que tiene como objetivo proporcion...   Quito      ec
# 1  Organizadora de R-Ladies Quito / Usuaria de R ...   Quito      ec
# 2                                                NaN   Quito      ec
# 3                                                NaN  Cuenca      ec
# 4                                                NaN   Quito      ec
#
#                                        group_profile         id  is_pro_admin  \
# 0  {'status': 'active', 'visited': 1552106450000,...  274228617         False
# 1  {'status': 'active', 'visited': 1552105491000,...  213001949         False
# 2  {'status': 'active', 'visited': 1552102958000,...  249923190         False
# 3  {'status': 'active', 'visited': 1552101439000,...  255612452         False
# 4  {'status': 'active', 'visited': 1552090034000,...  276160008         False
#
#           joined   lat localized_country_name    lon         name  \
# 0  1549913446000 -0.19                Ecuador -78.50  Pyladies E.
# 1  1473956368000 -0.19                Ecuador -78.50     Elena C.
# 2  1520684404000 -0.19                Ecuador -78.50   Marcelo C.
# 3  1527704432000 -2.90                Ecuador -79.01     David D.
# 4  1552089985000 -0.19                Ecuador -78.50    Carlos T.
#
#                                                photo state  status
# 0  {'id': 284993895, 'highres_link': 'https://sec...   NaN  active
# 1  {'id': 265497196, 'highres_link': 'https://sec...   NaN  active
# 2  {'id': 275420286, 'highres_link': 'https://sec...   NaN  active
# 3  {'id': 277634915, 'highres_link': 'https://sec...   NaN  active
# 4                                                NaN   NaN  active

# %% [markdown]
# ## Datos perdidos

# %% [markdown]
# **Delete**
# - .isna()
# - .notna()
# - .dropna()

# %%
membersDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 14 columns):
# bio                       7 non-null object
# city                      67 non-null object
# country                   67 non-null object
# group_profile             67 non-null object
# id                        67 non-null int64
# is_pro_admin              67 non-null bool
# joined                    67 non-null int64
# lat                       67 non-null float64
# localized_country_name    67 non-null object
# lon                       67 non-null float64
# name                      67 non-null object
# photo                     61 non-null object
# state                     3 non-null object
# status                    67 non-null object
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 6.9+ KB

# %%
missingState = membersDataFrame['state'].notna()

# %%
missingState.sum()
# Out:
# 3

# %%
membersDataFrame.drop("state", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-187-123f58b7ab5b> in <module>
# ----> 1 membersDataFrame.drop("state", axis=1, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['state'] not found in axis"

# %%
membersDataFrame
# Out:
#                                                   bio    city country  \
# 0   Es un grupo que tiene como objetivo proporcion...   Quito      ec
# 1   Organizadora de R-Ladies Quito / Usuaria de R ...   Quito      ec
# 2                                                 NaN   Quito      ec
# 3                                                 NaN  Cuenca      ec
# 4                                                 NaN   Quito      ec
# ..                                                ...     ...     ...
# 62                                                NaN   Quito      ec
# 63                                                NaN   Quito      ec
# 64                                                NaN   Quito      ec
# 65                                                NaN   Quito      ec
# 66                                                NaN   Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552106450000,...  274228617
# 1   {'status': 'active', 'visited': 1552105491000,...  213001949
# 2   {'status': 'active', 'visited': 1552102958000,...  249923190
# 3   {'status': 'active', 'visited': 1552101439000,...  255612452
# 4   {'status': 'active', 'visited': 1552090034000,...  276160008
# ..                                                ...        ...
# 62  {'status': 'active', 'visited': 1550679200000,...  246014322
# 63  {'status': 'active', 'visited': 1550630294000,...  274838317
# 64  {'status': 'active', 'visited': 1550628715000,...  238198836
# 65  {'status': 'active', 'visited': 1550628509000,...  272997265
# 66  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined   lat localized_country_name    lon  \
# 0          False  1549913446000 -0.19                Ecuador -78.50
# 1          False  1473956368000 -0.19                Ecuador -78.50
# 2          False  1520684404000 -0.19                Ecuador -78.50
# 3          False  1527704432000 -2.90                Ecuador -79.01
# 4          False  1552089985000 -0.19                Ecuador -78.50
# ..           ...            ...   ...                    ...    ...
# 62         False  1515952874000 -0.19                Ecuador -78.50
# 63         False  1550630269000 -0.19                Ecuador -78.50
# 64         False  1507240232000 -0.19                Ecuador -78.50
# 65         False  1548473211000 -0.19                Ecuador -78.50
# 66         False  1550624902000 -0.19                Ecuador -78.50
#
#              name                                              photo  status
# 0     Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...  active
# 1        Elena C.  {'id': 265497196, 'highres_link': 'https://sec...  active
# 2      Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...  active
# 3        David D.  {'id': 277634915, 'highres_link': 'https://sec...  active
# 4       Carlos T.                                                NaN  active
# ..            ...                                                ...     ...
# 62      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...  active
# 63      Andrea L.  {'id': 285260451, 'highres_link': 'https://sec...  active
# 64     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...  active
# 65  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...  active
# 66    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...  active
#
# [67 rows x 13 columns]

# %% [markdown]
# #### Filling missing values
# - .fillna()
# - .ffill()

# %%
membersDataFrame['bio'].fillna('Interés en aprender Python',inplace=True)

# %%
membersDataFrame
# Out:
#                                                   bio    city country  \
# 0   Es un grupo que tiene como objetivo proporcion...   Quito      ec
# 1   Organizadora de R-Ladies Quito / Usuaria de R ...   Quito      ec
# 2                          Interés en aprender Python   Quito      ec
# 3                          Interés en aprender Python  Cuenca      ec
# 4                          Interés en aprender Python   Quito      ec
# ..                                                ...     ...     ...
# 62                         Interés en aprender Python   Quito      ec
# 63                         Interés en aprender Python   Quito      ec
# 64                         Interés en aprender Python   Quito      ec
# 65                         Interés en aprender Python   Quito      ec
# 66                         Interés en aprender Python   Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552106450000,...  274228617
# 1   {'status': 'active', 'visited': 1552105491000,...  213001949
# 2   {'status': 'active', 'visited': 1552102958000,...  249923190
# 3   {'status': 'active', 'visited': 1552101439000,...  255612452
# 4   {'status': 'active', 'visited': 1552090034000,...  276160008
# ..                                                ...        ...
# 62  {'status': 'active', 'visited': 1550679200000,...  246014322
# 63  {'status': 'active', 'visited': 1550630294000,...  274838317
# 64  {'status': 'active', 'visited': 1550628715000,...  238198836
# 65  {'status': 'active', 'visited': 1550628509000,...  272997265
# 66  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined   lat localized_country_name    lon  \
# 0          False  1549913446000 -0.19                Ecuador -78.50
# 1          False  1473956368000 -0.19                Ecuador -78.50
# 2          False  1520684404000 -0.19                Ecuador -78.50
# 3          False  1527704432000 -2.90                Ecuador -79.01
# 4          False  1552089985000 -0.19                Ecuador -78.50
# ..           ...            ...   ...                    ...    ...
# 62         False  1515952874000 -0.19                Ecuador -78.50
# 63         False  1550630269000 -0.19                Ecuador -78.50
# 64         False  1507240232000 -0.19                Ecuador -78.50
# 65         False  1548473211000 -0.19                Ecuador -78.50
# 66         False  1550624902000 -0.19                Ecuador -78.50
#
#              name                                              photo  status
# 0     Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...  active
# 1        Elena C.  {'id': 265497196, 'highres_link': 'https://sec...  active
# 2      Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...  active
# 3        David D.  {'id': 277634915, 'highres_link': 'https://sec...  active
# 4       Carlos T.                                                NaN  active
# ..            ...                                                ...     ...
# 62      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...  active
# 63      Andrea L.  {'id': 285260451, 'highres_link': 'https://sec...  active
# 64     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...  active
# 65  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...  active
# 66    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...  active
#
# [67 rows x 13 columns]

# %%
membersDataFrame['photo'].fillna('',inplace=True)

# %%
membersDataFrame['field'].mean()

# %%
membersDataFrame
# Out:
#                                                   bio          city country  \
# 0   Es un grupo que tiene como objetivo proporcion...         Quito      ec
# 1   Organizadora de R-Ladies Quito / Usuaria de R ...         Quito      ec
# 2                          Interés en aprender Python         Quito      ec
# 3                          Interés en aprender Python        Cuenca      ec
# 4                          Interés en aprender Python         Quito      ec
# 5                          Interés en aprender Python  Buenos Aires      ar
# ..                                                ...           ...     ...
# 61                         Interés en aprender Python         Quito      ec
# 62                         Interés en aprender Python         Quito      ec
# 63                         Interés en aprender Python         Quito      ec
# 64                         Interés en aprender Python         Quito      ec
# 65                         Interés en aprender Python         Quito      ec
# 66                         Interés en aprender Python         Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552106450000,...  274228617
# 1   {'status': 'active', 'visited': 1552105491000,...  213001949
# 2   {'status': 'active', 'visited': 1552102958000,...  249923190
# 3   {'status': 'active', 'visited': 1552101439000,...  255612452
# 4   {'status': 'active', 'visited': 1552090034000,...  276160008
# 5   {'status': 'active', 'visited': 1552086286000,...  163123722
# ..                                                ...        ...
# 61  {'status': 'active', 'visited': 1550681949000,...  116955082
# 62  {'status': 'active', 'visited': 1550679200000,...  246014322
# 63  {'status': 'active', 'visited': 1550630294000,...  274838317
# 64  {'status': 'active', 'visited': 1550628715000,...  238198836
# 65  {'status': 'active', 'visited': 1550628509000,...  272997265
# 66  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined    lat localized_country_name    lon  \
# 0          False  1549913446000  -0.19                Ecuador -78.50
# 1          False  1473956368000  -0.19                Ecuador -78.50
# 2          False  1520684404000  -0.19                Ecuador -78.50
# 3          False  1527704432000  -2.90                Ecuador -79.01
# 4          False  1552089985000  -0.19                Ecuador -78.50
# 5          False  1408824136000 -34.61              Argentina -58.37
# ..           ...            ...    ...                    ...    ...
# 61         False  1382564434000  -0.19                Ecuador -78.50
# 62         False  1515952874000  -0.19                Ecuador -78.50
# 63         False  1550630269000  -0.19                Ecuador -78.50
# 64         False  1507240232000  -0.19                Ecuador -78.50
# 65         False  1548473211000  -0.19                Ecuador -78.50
# 66         False  1550624902000  -0.19                Ecuador -78.50
#
#                   name                                              photo  \
# 0          Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 1             Elena C.  {'id': 265497196, 'highres_link': 'https://sec...
# 2           Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...
# 3             David D.  {'id': 277634915, 'highres_link': 'https://sec...
# 4            Carlos T.
# 5   Francisco Silva G.  {'id': 220933812, 'highres_link': 'https://sec...
# ..                 ...                                                ...
# 61              damian  {'id': 256146960, 'highres_link': 'https://sec...
# 62           Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 63           Andrea L.  {'id': 285260451, 'highres_link': 'https://sec...
# 64          Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 65       Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 66         Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#     status
# 0   active
# 1   active
# 2   active
# 3   active
# 4   active
# 5   active
# ..     ...
# 61  active
# 62  active
# 63  active
# 64  active
# 65  active
# 66  active
#
# [67 rows x 13 columns]

# %% [markdown]
# ## Borrar espacios en blanco
# - .str.strip()

# %%
membersDataFrame['bio'].str.strip()
# Out:
# 0     Es un grupo que tiene como objetivo proporcion...
# 1     Organizadora de R-Ladies Quito / Usuaria de R ...
# 2                            Interés en aprender Python
# 3                            Interés en aprender Python
# 4                            Interés en aprender Python
# 5                            Interés en aprender Python
#                             ...
# 61                           Interés en aprender Python
# 62                           Interés en aprender Python
# 63                           Interés en aprender Python
# 64                           Interés en aprender Python
# 65                           Interés en aprender Python
# 66                           Interés en aprender Python
# Name: bio, Length: 67, dtype: object

# %% [markdown]
# ## Valores duplicados

# %%
membersDataFrame['id'].value_counts()
# Out:
# 250712955    1
# 234383621    1
# 186174514    1
# 275411889    1
# 108842032    1
# 274838317    1
#             ..
# 135803972    1
# 235493187    1
# 227211202    1
# 143902142    1
# 213839548    1
# 244641411    1
# Name: id, Length: 67, dtype: int64

# %%
membersDataFrame['name'].value_counts()
# Out:
# Andrea L.        2
# Roxana           1
# Andrea           1
# Lourdes B.       1
# Leo C.           1
# Luis Paz y M.    1
#                 ..
# Jimmy G.         1
# Anita S.         1
# Andrea C.        1
# Anar             1
# Mavelin A.       1
# Edison I.        1
# Name: name, Length: 66, dtype: int64

# %%
membersDataFrame.drop_duplicates(subset ="name", keep = False, inplace = True) 
membersDataFrame
# Out:
#                                                   bio          city country  \
# 0   Es un grupo que tiene como objetivo proporcion...         Quito      ec
# 1   Organizadora de R-Ladies Quito / Usuaria de R ...         Quito      ec
# 2                          Interés en aprender Python         Quito      ec
# 3                          Interés en aprender Python        Cuenca      ec
# 4                          Interés en aprender Python         Quito      ec
# 5                          Interés en aprender Python  Buenos Aires      ar
# ..                                                ...           ...     ...
# 60                         Interés en aprender Python         Quito      ec
# 61                         Interés en aprender Python         Quito      ec
# 62                         Interés en aprender Python         Quito      ec
# 64                         Interés en aprender Python         Quito      ec
# 65                         Interés en aprender Python         Quito      ec
# 66                         Interés en aprender Python         Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552106450000,...  274228617
# 1   {'status': 'active', 'visited': 1552105491000,...  213001949
# 2   {'status': 'active', 'visited': 1552102958000,...  249923190
# 3   {'status': 'active', 'visited': 1552101439000,...  255612452
# 4   {'status': 'active', 'visited': 1552090034000,...  276160008
# 5   {'status': 'active', 'visited': 1552086286000,...  163123722
# ..                                                ...        ...
# 60  {'status': 'active', 'visited': 1550682205000,...  194969949
# 61  {'status': 'active', 'visited': 1550681949000,...  116955082
# 62  {'status': 'active', 'visited': 1550679200000,...  246014322
# 64  {'status': 'active', 'visited': 1550628715000,...  238198836
# 65  {'status': 'active', 'visited': 1550628509000,...  272997265
# 66  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined    lat localized_country_name    lon  \
# 0          False  1549913446000  -0.19                Ecuador -78.50
# 1          False  1473956368000  -0.19                Ecuador -78.50
# 2          False  1520684404000  -0.19                Ecuador -78.50
# 3          False  1527704432000  -2.90                Ecuador -79.01
# 4          False  1552089985000  -0.19                Ecuador -78.50
# 5          False  1408824136000 -34.61              Argentina -58.37
# ..           ...            ...    ...                    ...    ...
# 60         False  1446426185000  -0.18                Ecuador -78.49
# 61         False  1382564434000  -0.19                Ecuador -78.50
# 62         False  1515952874000  -0.19                Ecuador -78.50
# 64         False  1507240232000  -0.19                Ecuador -78.50
# 65         False  1548473211000  -0.19                Ecuador -78.50
# 66         False  1550624902000  -0.19                Ecuador -78.50
#
#                   name                                              photo  \
# 0          Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 1             Elena C.  {'id': 265497196, 'highres_link': 'https://sec...
# 2           Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...
# 3             David D.  {'id': 277634915, 'highres_link': 'https://sec...
# 4            Carlos T.
# 5   Francisco Silva G.  {'id': 220933812, 'highres_link': 'https://sec...
# ..                 ...                                                ...
# 60            Anita S.  {'id': 251039573, 'highres_link': 'https://sec...
# 61              damian  {'id': 256146960, 'highres_link': 'https://sec...
# 62           Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 64          Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 65       Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 66         Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#     status
# 0   active
# 1   active
# 2   active
# 3   active
# 4   active
# 5   active
# ..     ...
# 60  active
# 61  active
# 62  active
# 64  active
# 65  active
# 66  active
#
# [65 rows x 13 columns]

# %%
membersDataFrame['name'].value_counts()
# Out:
# Roxana                1
# Francisco Silva G.    1
# Andrea                1
# Lourdes B.            1
# Leo C.                1
# Luis Paz y M.         1
#                      ..
# Jimmy G.              1
# Anita S.              1
# Andrea C.             1
# Anar                  1
# Mavelin A.            1
# Edison I.             1
# Name: name, Length: 65, dtype: int64

# %% [markdown]
# ## Normalizar tipos de datos

# %%
membersDataFrame['joined'] = pd.to_datetime(membersDataFrame['joined'],unit='ms')

# %%
membersDataFrame
# Out:
#                                                   bio          city country  \
# 0   Es un grupo que tiene como objetivo proporcion...         Quito      ec
# 1   Organizadora de R-Ladies Quito / Usuaria de R ...         Quito      ec
# 2                          Interés en aprender Python         Quito      ec
# 3                          Interés en aprender Python        Cuenca      ec
# 4                          Interés en aprender Python         Quito      ec
# 5                          Interés en aprender Python  Buenos Aires      ar
# ..                                                ...           ...     ...
# 60                         Interés en aprender Python         Quito      ec
# 61                         Interés en aprender Python         Quito      ec
# 62                         Interés en aprender Python         Quito      ec
# 64                         Interés en aprender Python         Quito      ec
# 65                         Interés en aprender Python         Quito      ec
# 66                         Interés en aprender Python         Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552106450000,...  274228617
# 1   {'status': 'active', 'visited': 1552105491000,...  213001949
# 2   {'status': 'active', 'visited': 1552102958000,...  249923190
# 3   {'status': 'active', 'visited': 1552101439000,...  255612452
# 4   {'status': 'active', 'visited': 1552090034000,...  276160008
# 5   {'status': 'active', 'visited': 1552086286000,...  163123722
# ..                                                ...        ...
# 60  {'status': 'active', 'visited': 1550682205000,...  194969949
# 61  {'status': 'active', 'visited': 1550681949000,...  116955082
# 62  {'status': 'active', 'visited': 1550679200000,...  246014322
# 64  {'status': 'active', 'visited': 1550628715000,...  238198836
# 65  {'status': 'active', 'visited': 1550628509000,...  272997265
# 66  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin              joined    lat localized_country_name    lon  \
# 0          False 2019-02-11 19:30:46  -0.19                Ecuador -78.50
# 1          False 2016-09-15 16:19:28  -0.19                Ecuador -78.50
# 2          False 2018-03-10 12:20:04  -0.19                Ecuador -78.50
# 3          False 2018-05-30 18:20:32  -2.90                Ecuador -79.01
# 4          False 2019-03-09 00:06:25  -0.19                Ecuador -78.50
# 5          False 2014-08-23 20:02:16 -34.61              Argentina -58.37
# ..           ...                 ...    ...                    ...    ...
# 60         False 2015-11-02 01:03:05  -0.18                Ecuador -78.49
# 61         False 2013-10-23 21:40:34  -0.19                Ecuador -78.50
# 62         False 2018-01-14 18:01:14  -0.19                Ecuador -78.50
# 64         False 2017-10-05 21:50:32  -0.19                Ecuador -78.50
# 65         False 2019-01-26 03:26:51  -0.19                Ecuador -78.50
# 66         False 2019-02-20 01:08:22  -0.19                Ecuador -78.50
#
#                   name                                              photo  \
# 0          Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 1             Elena C.  {'id': 265497196, 'highres_link': 'https://sec...
# 2           Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...
# 3             David D.  {'id': 277634915, 'highres_link': 'https://sec...
# 4            Carlos T.
# 5   Francisco Silva G.  {'id': 220933812, 'highres_link': 'https://sec...
# ..                 ...                                                ...
# 60            Anita S.  {'id': 251039573, 'highres_link': 'https://sec...
# 61              damian  {'id': 256146960, 'highres_link': 'https://sec...
# 62           Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 64          Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 65       Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 66         Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#     status
# 0   active
# 1   active
# 2   active
# 3   active
# 4   active
# 5   active
# ..     ...
# 60  active
# 61  active
# 62  active
# 64  active
# 65  active
# 66  active
#
# [65 rows x 13 columns]

# %% [markdown]
# ## Cambiar el index DataFrame

# %%
membersDataFrame.set_index('id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-226-92ab8f570580> in <module>
# ----> 1 membersDataFrame.set_index('id', inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'

# %%
membersDataFrame
# Out:
#                                                          bio          city  \
# id
# 274228617  Es un grupo que tiene como objetivo proporcion...         Quito
# 213001949  Organizadora de R-Ladies Quito / Usuaria de R ...         Quito
# 249923190                         Interés en aprender Python         Quito
# 255612452                         Interés en aprender Python        Cuenca
# 276160008                         Interés en aprender Python         Quito
# 163123722                         Interés en aprender Python  Buenos Aires
# ...                                                      ...           ...
# 194969949                         Interés en aprender Python         Quito
# 116955082                         Interés en aprender Python         Quito
# 246014322                         Interés en aprender Python         Quito
# 238198836                         Interés en aprender Python         Quito
# 272997265                         Interés en aprender Python         Quito
# 274833896                         Interés en aprender Python         Quito
#
#           country                                      group_profile  \
# id
# 274228617      ec  {'status': 'active', 'visited': 1552106450000,...
# 213001949      ec  {'status': 'active', 'visited': 1552105491000,...
# 249923190      ec  {'status': 'active', 'visited': 1552102958000,...
# 255612452      ec  {'status': 'active', 'visited': 1552101439000,...
# 276160008      ec  {'status': 'active', 'visited': 1552090034000,...
# 163123722      ar  {'status': 'active', 'visited': 1552086286000,...
# ...           ...                                                ...
# 194969949      ec  {'status': 'active', 'visited': 1550682205000,...
# 116955082      ec  {'status': 'active', 'visited': 1550681949000,...
# 246014322      ec  {'status': 'active', 'visited': 1550679200000,...
# 238198836      ec  {'status': 'active', 'visited': 1550628715000,...
# 272997265      ec  {'status': 'active', 'visited': 1550628509000,...
# 274833896      ec  {'status': 'active', 'visited': 1550624932000,...
#
#            is_pro_admin              joined    lat localized_country_name  \
# id
# 274228617         False 2019-02-11 19:30:46  -0.19                Ecuador
# 213001949         False 2016-09-15 16:19:28  -0.19                Ecuador
# 249923190         False 2018-03-10 12:20:04  -0.19                Ecuador
# 255612452         False 2018-05-30 18:20:32  -2.90                Ecuador
# 276160008         False 2019-03-09 00:06:25  -0.19                Ecuador
# 163123722         False 2014-08-23 20:02:16 -34.61              Argentina
# ...                 ...                 ...    ...                    ...
# 194969949         False 2015-11-02 01:03:05  -0.18                Ecuador
# 116955082         False 2013-10-23 21:40:34  -0.19                Ecuador
# 246014322         False 2018-01-14 18:01:14  -0.19                Ecuador
# 238198836         False 2017-10-05 21:50:32  -0.19                Ecuador
# 272997265         False 2019-01-26 03:26:51  -0.19                Ecuador
# 274833896         False 2019-02-20 01:08:22  -0.19                Ecuador
#
#              lon                name  \
# id
# 274228617 -78.50         Pyladies E.
# 213001949 -78.50            Elena C.
# 249923190 -78.50          Marcelo C.
# 255612452 -79.01            David D.
# 276160008 -78.50           Carlos T.
# 163123722 -58.37  Francisco Silva G.
# ...          ...                 ...
# 194969949 -78.49            Anita S.
# 116955082 -78.50              damian
# 246014322 -78.50           Alicia V.
# 238198836 -78.50          Eduardo V.
# 272997265 -78.50       Martha San A.
# 274833896 -78.50         Carolina B.
#
#                                                        photo  status
# id
# 274228617  {'id': 284993895, 'highres_link': 'https://sec...  active
# 213001949  {'id': 265497196, 'highres_link': 'https://sec...  active
# 249923190  {'id': 275420286, 'highres_link': 'https://sec...  active
# 255612452  {'id': 277634915, 'highres_link': 'https://sec...  active
# 276160008                                                     active
# 163123722  {'id': 220933812, 'highres_link': 'https://sec...  active
# ...                                                      ...     ...
# 194969949  {'id': 251039573, 'highres_link': 'https://sec...  active
# 116955082  {'id': 256146960, 'highres_link': 'https://sec...  active
# 246014322  {'id': 273816204, 'highres_link': 'https://sec...  active
# 238198836  {'id': 271271802, 'highres_link': 'https://sec...  active
# 272997265  {'id': 284487523, 'highres_link': 'https://sec...  active
# 274833896  {'id': 285258259, 'highres_link': 'https://sec...  active
#
# [65 rows x 12 columns]

# %% [markdown]
# ## Rename columns

# %%
membersDataFrame.rename(columns = {'joined':'date_joined'})
# Out:
#                                                          bio          city  \
# id
# 274228617  Es un grupo que tiene como objetivo proporcion...         Quito
# 213001949  Organizadora de R-Ladies Quito / Usuaria de R ...         Quito
# 249923190                         Interés en aprender Python         Quito
# 255612452                         Interés en aprender Python        Cuenca
# 276160008                         Interés en aprender Python         Quito
# 163123722                         Interés en aprender Python  Buenos Aires
# ...                                                      ...           ...
# 194969949                         Interés en aprender Python         Quito
# 116955082                         Interés en aprender Python         Quito
# 246014322                         Interés en aprender Python         Quito
# 238198836                         Interés en aprender Python         Quito
# 272997265                         Interés en aprender Python         Quito
# 274833896                         Interés en aprender Python         Quito
#
#           country                                      group_profile  \
# id
# 274228617      ec  {'status': 'active', 'visited': 1552106450000,...
# 213001949      ec  {'status': 'active', 'visited': 1552105491000,...
# 249923190      ec  {'status': 'active', 'visited': 1552102958000,...
# 255612452      ec  {'status': 'active', 'visited': 1552101439000,...
# 276160008      ec  {'status': 'active', 'visited': 1552090034000,...
# 163123722      ar  {'status': 'active', 'visited': 1552086286000,...
# ...           ...                                                ...
# 194969949      ec  {'status': 'active', 'visited': 1550682205000,...
# 116955082      ec  {'status': 'active', 'visited': 1550681949000,...
# 246014322      ec  {'status': 'active', 'visited': 1550679200000,...
# 238198836      ec  {'status': 'active', 'visited': 1550628715000,...
# 272997265      ec  {'status': 'active', 'visited': 1550628509000,...
# 274833896      ec  {'status': 'active', 'visited': 1550624932000,...
#
#            is_pro_admin         date_joined    lat localized_country_name  \
# id
# 274228617         False 2019-02-11 19:30:46  -0.19                Ecuador
# 213001949         False 2016-09-15 16:19:28  -0.19                Ecuador
# 249923190         False 2018-03-10 12:20:04  -0.19                Ecuador
# 255612452         False 2018-05-30 18:20:32  -2.90                Ecuador
# 276160008         False 2019-03-09 00:06:25  -0.19                Ecuador
# 163123722         False 2014-08-23 20:02:16 -34.61              Argentina
# ...                 ...                 ...    ...                    ...
# 194969949         False 2015-11-02 01:03:05  -0.18                Ecuador
# 116955082         False 2013-10-23 21:40:34  -0.19                Ecuador
# 246014322         False 2018-01-14 18:01:14  -0.19                Ecuador
# 238198836         False 2017-10-05 21:50:32  -0.19                Ecuador
# 272997265         False 2019-01-26 03:26:51  -0.19                Ecuador
# 274833896         False 2019-02-20 01:08:22  -0.19                Ecuador
#
#              lon                name  \
# id
# 274228617 -78.50         Pyladies E.
# 213001949 -78.50            Elena C.
# 249923190 -78.50          Marcelo C.
# 255612452 -79.01            David D.
# 276160008 -78.50           Carlos T.
# 163123722 -58.37  Francisco Silva G.
# ...          ...                 ...
# 194969949 -78.49            Anita S.
# 116955082 -78.50              damian
# 246014322 -78.50           Alicia V.
# 238198836 -78.50          Eduardo V.
# 272997265 -78.50       Martha San A.
# 274833896 -78.50         Carolina B.
#
#                                                        photo  status
# id
# 274228617  {'id': 284993895, 'highres_link': 'https://sec...  active
# 213001949  {'id': 265497196, 'highres_link': 'https://sec...  active
# 249923190  {'id': 275420286, 'highres_link': 'https://sec...  active
# 255612452  {'id': 277634915, 'highres_link': 'https://sec...  active
# 276160008                                                     active
# 163123722  {'id': 220933812, 'highres_link': 'https://sec...  active
# ...                                                      ...     ...
# 194969949  {'id': 251039573, 'highres_link': 'https://sec...  active
# 116955082  {'id': 256146960, 'highres_link': 'https://sec...  active
# 246014322  {'id': 273816204, 'highres_link': 'https://sec...  active
# 238198836  {'id': 271271802, 'highres_link': 'https://sec...  active
# 272997265  {'id': 284487523, 'highres_link': 'https://sec...  active
# 274833896  {'id': 285258259, 'highres_link': 'https://sec...  active
#
# [65 rows x 12 columns]

# %%
membersDataFrame = membersDataFrame.reindex(['name', 'bio', 'city','country','group_profile','is_pro_admin', 'date_joined','lat','lon', 'localized_country_name','photo', 'status'], axis="columns")

# %%
membersDataFrame
# Out:
#                        name  bio city country group_profile is_pro_admin  \
# id
# bio                     NaN  NaN  NaN     NaN           NaN          NaN
# city                    NaN  NaN  NaN     NaN           NaN          NaN
# country                 NaN  NaN  NaN     NaN           NaN          NaN
# group_profile           NaN  NaN  NaN     NaN           NaN          NaN
# is_pro_admin            NaN  NaN  NaN     NaN           NaN          NaN
# date_joined             NaN  NaN  NaN     NaN           NaN          NaN
# lat                     NaN  NaN  NaN     NaN           NaN          NaN
# localized_country_name  NaN  NaN  NaN     NaN           NaN          NaN
# lon                     NaN  NaN  NaN     NaN           NaN          NaN
# name                    NaN  NaN  NaN     NaN           NaN          NaN
# photo                   NaN  NaN  NaN     NaN           NaN          NaN
# status                  NaN  NaN  NaN     NaN           NaN          NaN
#
#                         date_joined  lat  lon localized_country_name photo  \
# id
# bio                             NaN  NaN  NaN                    NaN   NaN
# city                            NaN  NaN  NaN                    NaN   NaN
# country                         NaN  NaN  NaN                    NaN   NaN
# group_profile                   NaN  NaN  NaN                    NaN   NaN
# is_pro_admin                    NaN  NaN  NaN                    NaN   NaN
# date_joined                     NaN  NaN  NaN                    NaN   NaN
# lat                             NaN  NaN  NaN                    NaN   NaN
# localized_country_name          NaN  NaN  NaN                    NaN   NaN
# lon                             NaN  NaN  NaN                    NaN   NaN
# name                            NaN  NaN  NaN                    NaN   NaN
# photo                           NaN  NaN  NaN                    NaN   NaN
# status                          NaN  NaN  NaN                    NaN   NaN
#
#                        status
# id
# bio                       NaN
# city                      NaN
# country                   NaN
# group_profile             NaN
# is_pro_admin              NaN
# date_joined               NaN
# lat                       NaN
# localized_country_name    NaN
# lon                       NaN
# name                      NaN
# photo                     NaN
# status                    NaN

# %% [markdown]
# ## Guardar Resultdos

# %%
membersDataFrame.to_csv('membersMeetupPladies.csv', encoding='utf-8')
