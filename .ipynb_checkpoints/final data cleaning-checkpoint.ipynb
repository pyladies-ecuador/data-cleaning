# %% [markdown]
# # Limpieza de datos con Pandas

# %%
import requests
import pandas as pd
import hashlib

# %% [markdown]
# ## Extrar data api meetup

# %%
members = requests.get('https://api.meetup.com/pyladiesEc/members')

# %%
members?

# %%
members.json()

# %% [markdown]
# ## Convertir  DataFrame

# %%
membersDataFrame = pd.DataFrame(members.json())

# %%
membersDataFrame
# Out:
#                                                   bio        city country  \
# 0   Es un grupo que tiene como objetivo proporcion...       Quito      ec
# 1   entusiasta por aprender cosas relacionadas con...        Loja      ec
# 2   Estudiante de Maestría en Sistemas Inteligente...       Quito      ec
# 3                                                 NaN       Quito      ec
# 4                                                 NaN       Quito      ec
# 5                                                 NaN       Quito      ec
# 6                                                 NaN      Cuenca      ec
# 7                                                 NaN       Quito      ec
# 8                                                 NaN   Guayaquil      ec
# 9                                                 NaN       Quito      ec
# 10                                                NaN       Quito      ec
# 11                                                NaN       Quito      ec
# 12                                                NaN       Quito      ec
# 13                                                NaN       Quito      ec
# 14                         Desarrolladora de Software       Quito      ec
# 15                                                NaN   Guayaquil      ec
# 16                                                NaN       Quito      ec
# 17                                                NaN       Quito      ec
# 18                                                NaN       Quito      ec
# 19                                                NaN       Quito      ec
# 20                                                NaN       Quito      ec
# 21                                                NaN       Quito      ec
# 22                                                NaN       Quito      ec
# 23                                                NaN       Quito      ec
# 24                                                NaN       Quito      ec
# 25                                                NaN       Quito      ec
# 26                                                NaN    Bethesda      us
# 27                                                NaN       Quito      ec
# 28                                                NaN       Quito      ec
# 29                                                NaN      Cuenca      ec
# ..                                                ...         ...     ...
# 35                                                NaN       Quito      ec
# 36                                                NaN       Quito      ec
# 37                                                NaN  Northville      us
# 38                                                NaN      Cuenca      ec
# 39                                                NaN       Quito      ec
# 40                                                NaN       Quito      ec
# 41                                                NaN       Quito      ec
# 42                                                NaN       Quito      ec
# 43                                                NaN       Quito      ec
# 44                                                NaN       Quito      ec
# 45                                                NaN       Quito      ec
# 46  Organizadora de R-Ladies Quito / Usuaria de R ...       Quito      ec
# 47                   Llevando luz digital a la PyMes.       Quito      ec
# 48                                                NaN       Quito      ec
# 49                                                NaN       Quito      ec
# 50                                                NaN       Quito      ec
# 51                                                NaN       Quito      ec
# 52                                                NaN       Quito      ec
# 53                                                NaN       Quito      ec
# 54  Soy esposa, madre, emprendedora y empresaria Q...       Quito      ec
# 55                                                NaN       Quito      ec
# 56                                                NaN       Quito      ec
# 57                                                NaN       Quito      ec
# 58                                                NaN       Quito      ec
# 59                                                NaN       Quito      ec
# 60                                                NaN       Quito      ec
# 61                                                NaN       Quito      ec
# 62                                                NaN       Quito      ec
# 63                                                NaN       Quito      ec
# 64                                                NaN       Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552000383000,...  274228617
# 1   {'status': 'active', 'visited': 1552081166000,...  276151888
# 2   {'status': 'active', 'visited': 1552080611000,...  276151566
# 3   {'status': 'active', 'visited': 1552078775000,...  256300260
# 4   {'status': 'active', 'visited': 1552077570000,...  235853540
# 5   {'status': 'active', 'visited': 1552070345000,...  244641411
# 6   {'status': 'active', 'visited': 1552062632000,...  274959456
# 7   {'status': 'active', 'visited': 1552062452000,...  264099108
# 8   {'status': 'active', 'visited': 1552061417000,...  276101328
# 9   {'status': 'active', 'visited': 1552061024000,...  235493187
# 10  {'status': 'active', 'visited': 1552049994000,...  245597047
# 11  {'status': 'active', 'visited': 1552044284000,...  227211202
# 12  {'status': 'active', 'visited': 1552043737000,...  250902965
# 13  {'status': 'active', 'visited': 1552041469000,...  273201949
# 14  {'title': 'PyLady', 'status': 'active', 'visit...  247732691
# 15  {'status': 'active', 'visited': 1552011561000,...  276020102
# 16  {'status': 'active', 'visited': 1552001330000,...  276089997
# 17  {'status': 'active', 'visited': 1552001294000,...  249923190
# 18  {'status': 'active', 'visited': 1551991909000,...  267202489
# 19  {'status': 'active', 'visited': 1551979004000,...  268797456
# 20  {'status': 'active', 'visited': 1551978872000,...  135803972
# 21  {'status': 'active', 'visited': 1551923447000,...  276017288
# 22  {'status': 'active', 'visited': 1551919534000,...  276013944
# 23  {'status': 'active', 'visited': 1551903787000,...  275999062
# 24  {'status': 'active', 'visited': 1551901214000,...  275993243
# 25  {'status': 'active', 'visited': 1551886167000,...  274878775
# 26  {'status': 'active', 'visited': 1551859587000,...  143902142
# 27  {'status': 'active', 'visited': 1551835694000,...  250712955
# 28  {'status': 'active', 'visited': 1551807233000,...  273802988
# 29  {'status': 'active', 'visited': 1551752572000,...  255612452
# ..                                                ...        ...
# 35  {'status': 'active', 'visited': 1551462195000,...  275583623
# 36  {'status': 'active', 'visited': 1551390676000,...  186174514
# 37  {'status': 'active', 'visited': 1551271805000,...  254946768
# 38  {'status': 'active', 'visited': 1551241397000,...  266389745
# 39  {'status': 'active', 'visited': 1551240684000,...  275411889
# 40  {'status': 'active', 'visited': 1551238688000,...  250385747
# 41  {'status': 'active', 'visited': 1551207475000,...   53512742
# 42  {'status': 'active', 'visited': 1551194612000,...  275367061
# 43  {'status': 'active', 'visited': 1551192450000,...  259030358
# 44  {'status': 'active', 'visited': 1551169770000,...  259070684
# 45  {'status': 'active', 'visited': 1551125078000,...  237977896
# 46  {'status': 'active', 'visited': 1550980082000,...  213001949
# 47  {'status': 'active', 'visited': 1550955518000,...  198579333
# 48  {'status': 'active', 'visited': 1550897644000,...  268755677
# 49  {'status': 'active', 'visited': 1550896049000,...  262025070
# 50  {'status': 'active', 'visited': 1550889723000,...  269932525
# 51  {'status': 'active', 'visited': 1550875866000,...  273396042
# 52  {'status': 'active', 'visited': 1550804403000,...  273078108
# 53  {'status': 'active', 'visited': 1550773382000,...  234383621
# 54  {'status': 'active', 'visited': 1550758779000,...  257319462
# 55  {'status': 'active', 'visited': 1550721779000,...  108842032
# 56  {'status': 'active', 'visited': 1550683865000,...  262397218
# 57  {'status': 'active', 'visited': 1550683543000,...  259539676
# 58  {'status': 'active', 'visited': 1550682205000,...  194969949
# 59  {'status': 'active', 'visited': 1550681949000,...  116955082
# 60  {'status': 'active', 'visited': 1550679200000,...  246014322
# 61  {'status': 'active', 'visited': 1550630294000,...  274838317
# 62  {'status': 'active', 'visited': 1550628715000,...  238198836
# 63  {'status': 'active', 'visited': 1550628509000,...  272997265
# 64  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined    lat localized_country_name    lon  \
# 0          False  1549913446000  -0.19                Ecuador -78.50
# 1          False  1552080861000  -3.99                Ecuador -79.21
# 2          False  1552080453000  -0.19                Ecuador -78.50
# 3          False  1528495887000  -0.19                Ecuador -78.50
# 4          False  1504757368000  -0.19                Ecuador -78.50
# 5          False  1514321784000  -0.19                Ecuador -78.50
# 6          False  1550775169000  -2.90                Ecuador -79.01
# 7          False  1537920016000  -0.19                Ecuador -78.50
# 8          False  1552014741000  -2.21                Ecuador -79.90
# 9          False  1504384147000  -0.19                Ecuador -78.50
# 10         False  1515434709000  -0.19                Ecuador -78.50
# 11         False  1494276593000  -0.19                Ecuador -78.50
# 12         False  1521907209000  -0.19                Ecuador -78.50
# 13         False  1548695415000  -0.19                Ecuador -78.50
# 14         False  1518021245000  -0.19                Ecuador -78.50
# 15         False  1551926989000  -2.21                Ecuador -79.90
# 16         False  1552000823000  -0.19                Ecuador -78.50
# 17         False  1520684404000  -0.19                Ecuador -78.50
# 18         False  1541513415000  -0.19                Ecuador -78.50
# 19         False  1543508424000  -0.19                Ecuador -78.50
# 20         False  1393988782000  -0.19                Ecuador -78.50
# 21         False  1551923430000  -0.19                Ecuador -78.50
# 22         False  1551919402000  -0.19                Ecuador -78.50
# 23         False  1551903329000  -0.19                Ecuador -78.50
# 24         False  1551901176000  -0.19                Ecuador -78.50
# 25         False  1550682678000  -0.19                Ecuador -78.50
# 26         False  1398561957000  38.98                    USA -77.10
# 27         False  1521664947000  -0.19                Ecuador -78.50
# 28         False  1549397548000  -0.19                Ecuador -78.50
# 29         False  1527704432000  -2.90                Ecuador -79.01
# ..           ...            ...    ...                    ...    ...
# 35         False  1551462186000  -0.19                Ecuador -78.50
# 36         False  1429038397000  -0.19                Ecuador -78.50
# 37         False  1526868194000  42.42                    USA -83.47
# 38         False  1540516366000  -2.90                Ecuador -79.01
# 39         False  1551240672000  -0.19                Ecuador -78.50
# 40         False  1521248284000  -0.19                Ecuador -78.50
# 41         False  1341380552000  -0.19                Ecuador -78.50
# 42         False  1551194241000  -0.19                Ecuador -78.50
# 43         False  1531778618000  -0.19                Ecuador -78.50
# 44         False  1531832013000  -0.19                Ecuador -78.50
# 45         False  1507003583000  -0.19                Ecuador -78.50
# 46         False  1473956368000  -0.19                Ecuador -78.50
# 47         False  1453680146000  -0.19                Ecuador -78.50
# 48         False  1543451971000  -0.19                Ecuador -78.50
# 49         False  1535432731000  -0.19                Ecuador -78.50
# 50         False  1544901107000  -0.19                Ecuador -78.50
# 51         False  1548896839000  -0.19                Ecuador -78.50
# 52         False  1548561862000  -0.19                Ecuador -78.50
# 53         False  1503116303000  -0.19                Ecuador -78.50
# 54         False  1529758716000  -0.19                Ecuador -78.50
# 55         False  1377743733000  -0.19                Ecuador -78.50
# 56         False  1535908543000  -0.19                Ecuador -78.50
# 57         False  1532393560000  -0.19                Ecuador -78.50
# 58         False  1446426185000  -0.18                Ecuador -78.49
# 59         False  1382564434000  -0.19                Ecuador -78.50
# 60         False  1515952874000  -0.19                Ecuador -78.50
# 61         False  1550630269000  -0.19                Ecuador -78.50
# 62         False  1507240232000  -0.19                Ecuador -78.50
# 63         False  1548473211000  -0.19                Ecuador -78.50
# 64         False  1550624902000  -0.19                Ecuador -78.50
#
#                       name                                              photo  \
# 0              Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 1               Jessica M.                                                NaN
# 2                 Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...
# 3                   Leo C.  {'id': 277908461, 'highres_link': 'https://sec...
# 4            Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...
# 5                Andrea C.  {'id': 273313080, 'highres_link': 'https://sec...
# 6                 Jorge A.  {'id': 285317717, 'highres_link': 'https://sec...
# 7                   Ingrid  {'id': 280981629, 'highres_link': 'https://sec...
# 8                  Iván P.  {'id': 285810280, 'highres_link': 'https://sec...
# 9                   Andrea  {'id': 279505242, 'highres_link': 'https://sec...
# 10            Katherine M.  {'id': 273639156, 'highres_link': 'https://sec...
# 11     Rommel Gutiérrez R.  {'id': 266752098, 'highres_link': 'https://sec...
# 12                 Gabi M.  {'id': 275808782, 'highres_link': 'https://sec...
# 13                Mayra O.  {'id': 284564436, 'highres_link': 'https://sec...
# 14                 Gaby G.  {'id': 274529570, 'highres_link': 'https://sec...
# 15               Mirely T.  {'id': 285772660, 'highres_link': 'https://sec...
# 16                    Daya                                                NaN
# 17              Marcelo C.  {'id': 275420286, 'highres_link': 'https://sec...
# 18        Andrea Esther M.  {'id': 282182737, 'highres_link': 'https://sec...
# 19                Paola C.  {'id': 282812113, 'highres_link': 'https://sec...
# 20                 rojoyin  {'id': 265333270, 'highres_link': 'https://sec...
# 21              Eduardo R.  {'id': 285771282, 'highres_link': 'https://sec...
# 22                Jimmy G.  {'id': 285769528, 'highres_link': 'https://sec...
# 23               Sandra R.  {'id': 285762009, 'highres_link': 'https://sec...
# 24               Sttefy C.                                                NaN
# 25                 Paolo P  {'id': 285280202, 'highres_link': 'https://sec...
# 26                   Katya  {'id': 265632334, 'highres_link': 'https://sec...
# 27                Rocío E.  {'id': 275735026, 'highres_link': 'https://sec...
# 28                 Angel G                                                NaN
# 29                David D.  {'id': 277634915, 'highres_link': 'https://sec...
# ..                     ...                                                ...
# 35               Raquel V.  {'id': 285596328, 'highres_link': 'https://sec...
# 36              Marcelo M.  {'id': 245352027, 'highres_link': 'https://sec...
# 37  Krlos A Guaillazaca G.  {'id': 277378185, 'highres_link': 'https://sec...
# 38       Diana Carolina B.  {'id': 281868492, 'highres_link': 'https://sec...
# 39                danny r.  {'id': 285506861, 'highres_link': 'https://sec...
# 40            Hugo Dario T  {'id': 275601645, 'highres_link': 'https://sec...
# 41                 Galo L.  {'id': 194248112, 'highres_link': 'https://sec...
# 42              Adriana R.  {'id': 285483601, 'highres_link': 'https://sec...
# 43              Mavelin A.  {'id': 279192632, 'highres_link': 'https://sec...
# 44               Ximena C.  {'id': 278951440, 'highres_link': 'https://sec...
# 45            Alexandra H.  {'id': 271190712, 'highres_link': 'https://sec...
# 46                Elena C.  {'id': 265497196, 'highres_link': 'https://sec...
# 47              Lourdes B.  {'id': 258650314, 'highres_link': 'https://sec...
# 48                    Viga  {'id': 282795829, 'highres_link': 'https://sec...
# 49               Alexandra                                                NaN
# 50    Washington Fierro S.  {'id': 283304032, 'highres_link': 'https://sec...
# 51               Andrea L.  {'id': 284642301, 'highres_link': 'https://sec...
# 52                Santiago  {'id': 285329401, 'highres_link': 'https://sec...
# 53                 Lina C.  {'id': 269847044, 'highres_link': 'https://sec...
# 54                Katya A.  {'id': 282786327, 'highres_link': 'https://sec...
# 55                  wilmer  {'id': 277630980, 'highres_link': 'https://sec...
# 56                  Roxana  {'id': 280295458, 'highres_link': 'https://sec...
# 57               Elymar A.  {'id': 279137929, 'highres_link': 'https://sec...
# 58                Anita S.  {'id': 251039573, 'highres_link': 'https://sec...
# 59                  damian  {'id': 256146960, 'highres_link': 'https://sec...
# 60               Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 61               Andrea L.  {'id': 285260451, 'highres_link': 'https://sec...
# 62              Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 63           Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 64             Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#    state  status
# 0    NaN  active
# 1    NaN  active
# 2    NaN  active
# 3    NaN  active
# 4    NaN  active
# 5    NaN  active
# 6    NaN  active
# 7    NaN  active
# 8    NaN  active
# 9    NaN  active
# 10   NaN  active
# 11   NaN  active
# 12   NaN  active
# 13   NaN  active
# 14   NaN  active
# 15   NaN  active
# 16   NaN  active
# 17   NaN  active
# 18   NaN  active
# 19   NaN  active
# 20   NaN  active
# 21   NaN  active
# 22   NaN  active
# 23   NaN  active
# 24   NaN  active
# 25   NaN  active
# 26    MD  active
# 27   NaN  active
# 28   NaN  active
# 29   NaN  active
# ..   ...     ...
# 35   NaN  active
# 36   NaN  active
# 37    MI  active
# 38   NaN  active
# 39   NaN  active
# 40   NaN  active
# 41   NaN  active
# 42   NaN  active
# 43   NaN  active
# 44   NaN  active
# 45   NaN  active
# 46   NaN  active
# 47   NaN  active
# 48   NaN  active
# 49   NaN  active
# 50   NaN  active
# 51   NaN  active
# 52   NaN  active
# 53   NaN  active
# 54   NaN  active
# 55   NaN  active
# 56   NaN  active
# 57   NaN  active
# 58   NaN  active
# 59   NaN  active
# 60   NaN  active
# 61   NaN  active
# 62   NaN  active
# 63   NaN  active
# 64   NaN  active
#
# [65 rows x 14 columns]

# %%
membersDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 14 columns):
# bio                       7 non-null object
# city                      65 non-null object
# country                   65 non-null object
# group_profile             65 non-null object
# id                        65 non-null int64
# is_pro_admin              65 non-null bool
# joined                    65 non-null int64
# lat                       65 non-null float64
# localized_country_name    65 non-null object
# lon                       65 non-null float64
# name                      65 non-null object
# photo                     60 non-null object
# state                     3 non-null object
# status                    65 non-null object
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 6.7+ KB

# %% [markdown]
# #### Limit the number of rows to show

# %%
pd.options.display.max_rows = 10

# %%
membersDataFrame.tail() #Five Last rows

# %%
membersDataFrame.head()#Five first rows
# Out:
#                                                  bio   city country  \
# 0  Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 1  entusiasta por aprender cosas relacionadas con...   Loja      ec
# 2  Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 3                                                NaN  Quito      ec
# 4                                                NaN  Quito      ec
#
#                                        group_profile         id  is_pro_admin  \
# 0  {'status': 'active', 'visited': 1552000383000,...  274228617         False
# 1  {'status': 'active', 'visited': 1552081166000,...  276151888         False
# 2  {'status': 'active', 'visited': 1552080611000,...  276151566         False
# 3  {'status': 'active', 'visited': 1552078775000,...  256300260         False
# 4  {'status': 'active', 'visited': 1552077570000,...  235853540         False
#
#           joined   lat localized_country_name    lon           name  \
# 0  1549913446000 -0.19                Ecuador -78.50    Pyladies E.
# 1  1552080861000 -3.99                Ecuador -79.21     Jessica M.
# 2  1552080453000 -0.19                Ecuador -78.50       Silvy V.
# 3  1528495887000 -0.19                Ecuador -78.50         Leo C.
# 4  1504757368000 -0.19                Ecuador -78.50  Luis Paz y M.
#
#                                                photo state  status
# 0  {'id': 284993895, 'highres_link': 'https://sec...   NaN  active
# 1                                                NaN   NaN  active
# 2  {'id': 285836294, 'highres_link': 'https://sec...   NaN  active
# 3  {'id': 277908461, 'highres_link': 'https://sec...   NaN  active
# 4  {'id': 270416997, 'highres_link': 'https://sec...   NaN  active

# %% [markdown]
# ## Datos perdidos

# %% [markdown]
# **Delete**
# - .isna()
# - .notna()
# - .dropna()

# %%
membersDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 14 columns):
# bio                       7 non-null object
# city                      65 non-null object
# country                   65 non-null object
# group_profile             65 non-null object
# id                        65 non-null int64
# is_pro_admin              65 non-null bool
# joined                    65 non-null int64
# lat                       65 non-null float64
# localized_country_name    65 non-null object
# lon                       65 non-null float64
# name                      65 non-null object
# photo                     60 non-null object
# state                     3 non-null object
# status                    65 non-null object
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 6.7+ KB

# %%
missingState = membersDataFrame['state'].notna()

# %%
missingState.sum()
# Out:
# 3

# %%
membersDataFrame.drop("state", axis=1)

# %% [markdown]
# ## Borrar espacios en blanco

# %%
membersDataFrame['bio'].str.strip()
# Out:
# id
# 274228617    Es un grupo que tiene como objetivo proporcion...
# 276151888    entusiasta por aprender cosas relacionadas con...
# 276151566    Estudiante de Maestría en Sistemas Inteligente...
# 256300260                                                  NaN
# 235853540                                                  NaN
#                                    ...
# 116955082                                                  NaN
# 246014322                                                  NaN
# 238198836                                                  NaN
# 272997265                                                  NaN
# 274833896                                                  NaN
# Name: bio, Length: 63, dtype: object

# %% [markdown]
# #### Filling missing values
# - .fillna()
# - .ffill()

# %%
membersDataFrame.fillna(0)
membersDataFrame.mean()
membersDataFrame['bio'].fillna('Interés en aprender Python',inplace=True)

# %%
membersDataFrame
# Out:
#                                                          bio   city country  \
# id
# 274228617  Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 276151888  entusiasta por aprender cosas relacionadas con...   Loja      ec
# 276151566  Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 256300260                         Interés en aprender Python  Quito      ec
# 235853540                         Interés en aprender Python  Quito      ec
# ...                                                      ...    ...     ...
# 116955082                         Interés en aprender Python  Quito      ec
# 246014322                         Interés en aprender Python  Quito      ec
# 238198836                         Interés en aprender Python  Quito      ec
# 272997265                         Interés en aprender Python  Quito      ec
# 274833896                         Interés en aprender Python  Quito      ec
#
#                                                group_profile  is_pro_admin  \
# id
# 274228617  {'status': 'active', 'visited': 1552000383000,...         False
# 276151888  {'status': 'active', 'visited': 1552081166000,...         False
# 276151566  {'status': 'active', 'visited': 1552080611000,...         False
# 256300260  {'status': 'active', 'visited': 1552078775000,...         False
# 235853540  {'status': 'active', 'visited': 1552077570000,...         False
# ...                                                      ...           ...
# 116955082  {'status': 'active', 'visited': 1550681949000,...         False
# 246014322  {'status': 'active', 'visited': 1550679200000,...         False
# 238198836  {'status': 'active', 'visited': 1550628715000,...         False
# 272997265  {'status': 'active', 'visited': 1550628509000,...         False
# 274833896  {'status': 'active', 'visited': 1550624932000,...         False
#
#                        joined   lat localized_country_name    lon  \
# id
# 274228617 2019-02-11 19:30:46 -0.19                Ecuador -78.50
# 276151888 2019-03-08 21:34:21 -3.99                Ecuador -79.21
# 276151566 2019-03-08 21:27:33 -0.19                Ecuador -78.50
# 256300260 2018-06-08 22:11:27 -0.19                Ecuador -78.50
# 235853540 2017-09-07 04:09:28 -0.19                Ecuador -78.50
# ...                       ...   ...                    ...    ...
# 116955082 2013-10-23 21:40:34 -0.19                Ecuador -78.50
# 246014322 2018-01-14 18:01:14 -0.19                Ecuador -78.50
# 238198836 2017-10-05 21:50:32 -0.19                Ecuador -78.50
# 272997265 2019-01-26 03:26:51 -0.19                Ecuador -78.50
# 274833896 2019-02-20 01:08:22 -0.19                Ecuador -78.50
#
#                     name                                              photo  \
# id
# 274228617    Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 276151888     Jessica M.                                                NaN
# 276151566       Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...
# 256300260         Leo C.  {'id': 277908461, 'highres_link': 'https://sec...
# 235853540  Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...
# ...                  ...                                                ...
# 116955082         damian  {'id': 256146960, 'highres_link': 'https://sec...
# 246014322      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 238198836     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 272997265  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 274833896    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#           state  status
# id
# 274228617   NaN  active
# 276151888   NaN  active
# 276151566   NaN  active
# 256300260   NaN  active
# 235853540   NaN  active
# ...         ...     ...
# 116955082   NaN  active
# 246014322   NaN  active
# 238198836   NaN  active
# 272997265   NaN  active
# 274833896   NaN  active
#
# [63 rows x 13 columns]

# %%
membersDataFrame
# Out:
#                                                          bio   city country  \
# id
# 274228617  Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 276151888  entusiasta por aprender cosas relacionadas con...   Loja      ec
# 276151566  Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 256300260                                                NaN  Quito      ec
# 235853540                                                NaN  Quito      ec
# ...                                                      ...    ...     ...
# 116955082                                                NaN  Quito      ec
# 246014322                                                NaN  Quito      ec
# 238198836                                                NaN  Quito      ec
# 272997265                                                NaN  Quito      ec
# 274833896                                                NaN  Quito      ec
#
#                                                group_profile  is_pro_admin  \
# id
# 274228617  {'status': 'active', 'visited': 1552000383000,...         False
# 276151888  {'status': 'active', 'visited': 1552081166000,...         False
# 276151566  {'status': 'active', 'visited': 1552080611000,...         False
# 256300260  {'status': 'active', 'visited': 1552078775000,...         False
# 235853540  {'status': 'active', 'visited': 1552077570000,...         False
# ...                                                      ...           ...
# 116955082  {'status': 'active', 'visited': 1550681949000,...         False
# 246014322  {'status': 'active', 'visited': 1550679200000,...         False
# 238198836  {'status': 'active', 'visited': 1550628715000,...         False
# 272997265  {'status': 'active', 'visited': 1550628509000,...         False
# 274833896  {'status': 'active', 'visited': 1550624932000,...         False
#
#                        joined   lat localized_country_name    lon  \
# id
# 274228617 2019-02-11 19:30:46 -0.19                Ecuador -78.50
# 276151888 2019-03-08 21:34:21 -3.99                Ecuador -79.21
# 276151566 2019-03-08 21:27:33 -0.19                Ecuador -78.50
# 256300260 2018-06-08 22:11:27 -0.19                Ecuador -78.50
# 235853540 2017-09-07 04:09:28 -0.19                Ecuador -78.50
# ...                       ...   ...                    ...    ...
# 116955082 2013-10-23 21:40:34 -0.19                Ecuador -78.50
# 246014322 2018-01-14 18:01:14 -0.19                Ecuador -78.50
# 238198836 2017-10-05 21:50:32 -0.19                Ecuador -78.50
# 272997265 2019-01-26 03:26:51 -0.19                Ecuador -78.50
# 274833896 2019-02-20 01:08:22 -0.19                Ecuador -78.50
#
#                     name                                              photo  \
# id
# 274228617    Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 276151888     Jessica M.                                                NaN
# 276151566       Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...
# 256300260         Leo C.  {'id': 277908461, 'highres_link': 'https://sec...
# 235853540  Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...
# ...                  ...                                                ...
# 116955082         damian  {'id': 256146960, 'highres_link': 'https://sec...
# 246014322      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 238198836     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 272997265  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 274833896    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#           state  status
# id
# 274228617   NaN  active
# 276151888   NaN  active
# 276151566   NaN  active
# 256300260   NaN  active
# 235853540   NaN  active
# ...         ...     ...
# 116955082   NaN  active
# 246014322   NaN  active
# 238198836   NaN  active
# 272997265   NaN  active
# 274833896   NaN  active
#
# [63 rows x 13 columns]

# %% [markdown]
# ## Valores duplicados

# %%
membersDataFrame['id'].value_counts()
# Out:
# 250712955    1
# 276151888    1
# 238198836    1
# 186174514    1
# 275411889    1
#             ..
# 135803972    1
# 235493187    1
# 227211202    1
# 143902142    1
# 244641411    1
# Name: id, Length: 63, dtype: int64

# %%
membersDataFrame['name'].value_counts()
# Out:
# Roxana           1
# Daya             1
# Andrea           1
# Leo C.           1
# Luis Paz y M.    1
#                 ..
# Anita S.         1
# Andrea C.        1
# Anar             1
# Mavelin A.       1
# Edison I.        1
# Name: name, Length: 63, dtype: int64

# %%
membersDataFrame.drop_duplicates(subset ="name", keep = False, inplace = True) 
membersDataFrame
# Out:
#                                                   bio   city country  \
# 0   Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 1   entusiasta por aprender cosas relacionadas con...   Loja      ec
# 2   Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 3                                                 NaN  Quito      ec
# 4                                                 NaN  Quito      ec
# ..                                                ...    ...     ...
# 59                                                NaN  Quito      ec
# 60                                                NaN  Quito      ec
# 62                                                NaN  Quito      ec
# 63                                                NaN  Quito      ec
# 64                                                NaN  Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552000383000,...  274228617
# 1   {'status': 'active', 'visited': 1552081166000,...  276151888
# 2   {'status': 'active', 'visited': 1552080611000,...  276151566
# 3   {'status': 'active', 'visited': 1552078775000,...  256300260
# 4   {'status': 'active', 'visited': 1552077570000,...  235853540
# ..                                                ...        ...
# 59  {'status': 'active', 'visited': 1550681949000,...  116955082
# 60  {'status': 'active', 'visited': 1550679200000,...  246014322
# 62  {'status': 'active', 'visited': 1550628715000,...  238198836
# 63  {'status': 'active', 'visited': 1550628509000,...  272997265
# 64  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin         joined   lat localized_country_name    lon  \
# 0          False  1549913446000 -0.19                Ecuador -78.50
# 1          False  1552080861000 -3.99                Ecuador -79.21
# 2          False  1552080453000 -0.19                Ecuador -78.50
# 3          False  1528495887000 -0.19                Ecuador -78.50
# 4          False  1504757368000 -0.19                Ecuador -78.50
# ..           ...            ...   ...                    ...    ...
# 59         False  1382564434000 -0.19                Ecuador -78.50
# 60         False  1515952874000 -0.19                Ecuador -78.50
# 62         False  1507240232000 -0.19                Ecuador -78.50
# 63         False  1548473211000 -0.19                Ecuador -78.50
# 64         False  1550624902000 -0.19                Ecuador -78.50
#
#              name                                              photo state  \
# 0     Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...   NaN
# 1      Jessica M.                                                NaN   NaN
# 2        Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...   NaN
# 3          Leo C.  {'id': 277908461, 'highres_link': 'https://sec...   NaN
# 4   Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...   NaN
# ..            ...                                                ...   ...
# 59         damian  {'id': 256146960, 'highres_link': 'https://sec...   NaN
# 60      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...   NaN
# 62     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...   NaN
# 63  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...   NaN
# 64    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...   NaN
#
#     status
# 0   active
# 1   active
# 2   active
# 3   active
# 4   active
# ..     ...
# 59  active
# 60  active
# 62  active
# 63  active
# 64  active
#
# [63 rows x 14 columns]

# %%
membersDataFrame['name'].value_counts()
# Out:
# Roxana           1
# Daya             1
# Andrea           1
# Leo C.           1
# Luis Paz y M.    1
#                 ..
# Anita S.         1
# Andrea C.        1
# Anar             1
# Mavelin A.       1
# Edison I.        1
# Name: name, Length: 63, dtype: int64

# %% [markdown]
# ## Normalizar tipos de datos

# %%
membersDataFrame['joined'] = pd.to_datetime(membersDataFrame['joined'],unit='ms')

# %%
membersDataFrame
# Out:
#                                                   bio   city country  \
# 0   Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 1   entusiasta por aprender cosas relacionadas con...   Loja      ec
# 2   Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 3                                                 NaN  Quito      ec
# 4                                                 NaN  Quito      ec
# ..                                                ...    ...     ...
# 59                                                NaN  Quito      ec
# 60                                                NaN  Quito      ec
# 62                                                NaN  Quito      ec
# 63                                                NaN  Quito      ec
# 64                                                NaN  Quito      ec
#
#                                         group_profile         id  \
# 0   {'status': 'active', 'visited': 1552000383000,...  274228617
# 1   {'status': 'active', 'visited': 1552081166000,...  276151888
# 2   {'status': 'active', 'visited': 1552080611000,...  276151566
# 3   {'status': 'active', 'visited': 1552078775000,...  256300260
# 4   {'status': 'active', 'visited': 1552077570000,...  235853540
# ..                                                ...        ...
# 59  {'status': 'active', 'visited': 1550681949000,...  116955082
# 60  {'status': 'active', 'visited': 1550679200000,...  246014322
# 62  {'status': 'active', 'visited': 1550628715000,...  238198836
# 63  {'status': 'active', 'visited': 1550628509000,...  272997265
# 64  {'status': 'active', 'visited': 1550624932000,...  274833896
#
#     is_pro_admin              joined   lat localized_country_name    lon  \
# 0          False 2019-02-11 19:30:46 -0.19                Ecuador -78.50
# 1          False 2019-03-08 21:34:21 -3.99                Ecuador -79.21
# 2          False 2019-03-08 21:27:33 -0.19                Ecuador -78.50
# 3          False 2018-06-08 22:11:27 -0.19                Ecuador -78.50
# 4          False 2017-09-07 04:09:28 -0.19                Ecuador -78.50
# ..           ...                 ...   ...                    ...    ...
# 59         False 2013-10-23 21:40:34 -0.19                Ecuador -78.50
# 60         False 2018-01-14 18:01:14 -0.19                Ecuador -78.50
# 62         False 2017-10-05 21:50:32 -0.19                Ecuador -78.50
# 63         False 2019-01-26 03:26:51 -0.19                Ecuador -78.50
# 64         False 2019-02-20 01:08:22 -0.19                Ecuador -78.50
#
#              name                                              photo state  \
# 0     Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...   NaN
# 1      Jessica M.                                                NaN   NaN
# 2        Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...   NaN
# 3          Leo C.  {'id': 277908461, 'highres_link': 'https://sec...   NaN
# 4   Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...   NaN
# ..            ...                                                ...   ...
# 59         damian  {'id': 256146960, 'highres_link': 'https://sec...   NaN
# 60      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...   NaN
# 62     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...   NaN
# 63  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...   NaN
# 64    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...   NaN
#
#     status
# 0   active
# 1   active
# 2   active
# 3   active
# 4   active
# ..     ...
# 59  active
# 60  active
# 62  active
# 63  active
# 64  active
#
# [63 rows x 14 columns]

# %% [markdown]
# ### Cambiar el index DataFrame

# %%
membersDataFrame['id'].is_unique
membersDataFrame.set_index('id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-9d3e35d1cb97> in <module>
# ----> 1 membersDataFrame['id'].is_unique
#       2 membersDataFrame.set_index('id', inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'

# %%
membersDataFrame
# Out:
#                                                          bio   city country  \
# id
# 274228617  Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 276151888  entusiasta por aprender cosas relacionadas con...   Loja      ec
# 276151566  Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 256300260                                                NaN  Quito      ec
# 235853540                                                NaN  Quito      ec
# ...                                                      ...    ...     ...
# 116955082                                                NaN  Quito      ec
# 246014322                                                NaN  Quito      ec
# 238198836                                                NaN  Quito      ec
# 272997265                                                NaN  Quito      ec
# 274833896                                                NaN  Quito      ec
#
#                                                group_profile  is_pro_admin  \
# id
# 274228617  {'status': 'active', 'visited': 1552000383000,...         False
# 276151888  {'status': 'active', 'visited': 1552081166000,...         False
# 276151566  {'status': 'active', 'visited': 1552080611000,...         False
# 256300260  {'status': 'active', 'visited': 1552078775000,...         False
# 235853540  {'status': 'active', 'visited': 1552077570000,...         False
# ...                                                      ...           ...
# 116955082  {'status': 'active', 'visited': 1550681949000,...         False
# 246014322  {'status': 'active', 'visited': 1550679200000,...         False
# 238198836  {'status': 'active', 'visited': 1550628715000,...         False
# 272997265  {'status': 'active', 'visited': 1550628509000,...         False
# 274833896  {'status': 'active', 'visited': 1550624932000,...         False
#
#                        joined   lat localized_country_name    lon  \
# id
# 274228617 2019-02-11 19:30:46 -0.19                Ecuador -78.50
# 276151888 2019-03-08 21:34:21 -3.99                Ecuador -79.21
# 276151566 2019-03-08 21:27:33 -0.19                Ecuador -78.50
# 256300260 2018-06-08 22:11:27 -0.19                Ecuador -78.50
# 235853540 2017-09-07 04:09:28 -0.19                Ecuador -78.50
# ...                       ...   ...                    ...    ...
# 116955082 2013-10-23 21:40:34 -0.19                Ecuador -78.50
# 246014322 2018-01-14 18:01:14 -0.19                Ecuador -78.50
# 238198836 2017-10-05 21:50:32 -0.19                Ecuador -78.50
# 272997265 2019-01-26 03:26:51 -0.19                Ecuador -78.50
# 274833896 2019-02-20 01:08:22 -0.19                Ecuador -78.50
#
#                     name                                              photo  \
# id
# 274228617    Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 276151888     Jessica M.                                                NaN
# 276151566       Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...
# 256300260         Leo C.  {'id': 277908461, 'highres_link': 'https://sec...
# 235853540  Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...
# ...                  ...                                                ...
# 116955082         damian  {'id': 256146960, 'highres_link': 'https://sec...
# 246014322      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 238198836     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 272997265  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 274833896    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#           state  status
# id
# 274228617   NaN  active
# 276151888   NaN  active
# 276151566   NaN  active
# 256300260   NaN  active
# 235853540   NaN  active
# ...         ...     ...
# 116955082   NaN  active
# 246014322   NaN  active
# 238198836   NaN  active
# 272997265   NaN  active
# 274833896   NaN  active
#
# [63 rows x 13 columns]

# %% [markdown]
# ### Rename columns

# %%
membersDataFrame.rename(columns = {'joined':'date_joined'})
# Out:
#                                                          bio   city country  \
# id
# 274228617  Es un grupo que tiene como objetivo proporcion...  Quito      ec
# 276151888  entusiasta por aprender cosas relacionadas con...   Loja      ec
# 276151566  Estudiante de Maestría en Sistemas Inteligente...  Quito      ec
# 256300260                         Interés en aprender Python  Quito      ec
# 235853540                         Interés en aprender Python  Quito      ec
# ...                                                      ...    ...     ...
# 116955082                         Interés en aprender Python  Quito      ec
# 246014322                         Interés en aprender Python  Quito      ec
# 238198836                         Interés en aprender Python  Quito      ec
# 272997265                         Interés en aprender Python  Quito      ec
# 274833896                         Interés en aprender Python  Quito      ec
#
#                                                group_profile  is_pro_admin  \
# id
# 274228617  {'status': 'active', 'visited': 1552000383000,...         False
# 276151888  {'status': 'active', 'visited': 1552081166000,...         False
# 276151566  {'status': 'active', 'visited': 1552080611000,...         False
# 256300260  {'status': 'active', 'visited': 1552078775000,...         False
# 235853540  {'status': 'active', 'visited': 1552077570000,...         False
# ...                                                      ...           ...
# 116955082  {'status': 'active', 'visited': 1550681949000,...         False
# 246014322  {'status': 'active', 'visited': 1550679200000,...         False
# 238198836  {'status': 'active', 'visited': 1550628715000,...         False
# 272997265  {'status': 'active', 'visited': 1550628509000,...         False
# 274833896  {'status': 'active', 'visited': 1550624932000,...         False
#
#                   date_joined   lat localized_country_name    lon  \
# id
# 274228617 2019-02-11 19:30:46 -0.19                Ecuador -78.50
# 276151888 2019-03-08 21:34:21 -3.99                Ecuador -79.21
# 276151566 2019-03-08 21:27:33 -0.19                Ecuador -78.50
# 256300260 2018-06-08 22:11:27 -0.19                Ecuador -78.50
# 235853540 2017-09-07 04:09:28 -0.19                Ecuador -78.50
# ...                       ...   ...                    ...    ...
# 116955082 2013-10-23 21:40:34 -0.19                Ecuador -78.50
# 246014322 2018-01-14 18:01:14 -0.19                Ecuador -78.50
# 238198836 2017-10-05 21:50:32 -0.19                Ecuador -78.50
# 272997265 2019-01-26 03:26:51 -0.19                Ecuador -78.50
# 274833896 2019-02-20 01:08:22 -0.19                Ecuador -78.50
#
#                     name                                              photo  \
# id
# 274228617    Pyladies E.  {'id': 284993895, 'highres_link': 'https://sec...
# 276151888     Jessica M.                                                NaN
# 276151566       Silvy V.  {'id': 285836294, 'highres_link': 'https://sec...
# 256300260         Leo C.  {'id': 277908461, 'highres_link': 'https://sec...
# 235853540  Luis Paz y M.  {'id': 270416997, 'highres_link': 'https://sec...
# ...                  ...                                                ...
# 116955082         damian  {'id': 256146960, 'highres_link': 'https://sec...
# 246014322      Alicia V.  {'id': 273816204, 'highres_link': 'https://sec...
# 238198836     Eduardo V.  {'id': 271271802, 'highres_link': 'https://sec...
# 272997265  Martha San A.  {'id': 284487523, 'highres_link': 'https://sec...
# 274833896    Carolina B.  {'id': 285258259, 'highres_link': 'https://sec...
#
#           state  status
# id
# 274228617   NaN  active
# 276151888   NaN  active
# 276151566   NaN  active
# 256300260   NaN  active
# 235853540   NaN  active
# ...         ...     ...
# 116955082   NaN  active
# 246014322   NaN  active
# 238198836   NaN  active
# 272997265   NaN  active
# 274833896   NaN  active
#
# [63 rows x 13 columns]

# %% [markdown]
# ### Guardar Resultdos

# %%
membersDataFrame.to_csv('membersMetup.csv', encoding='utf-8')
